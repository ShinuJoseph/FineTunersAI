# %%
''' import libraries
Autotokenizer: to count the number of tokens in a text
pipeline: to use the sentiment analysis model from huggingface
pandas: manipulate dataframes'''

from transformers import AutoTokenizer, pipeline
import pandas as pd

# %%
''' load the data'''

path_articles = r'FineTunersAI\Data\cleaned_output.csv'
news_articles = pd.read_csv(path_articles)

# %%
import pandas as pd
from bs4 import BeautifulSoup
import re

# Function to check if a paragraph is likely an ad or irrelevant
def is_irrelevant_paragraph(paragraph):
    text = paragraph.get_text().strip()
    if not text:
        return True
    if "menu-section-heading" in paragraph.get("class", []):
        return True
    if text.startswith("©") or "byline-bio" in paragraph.get("class", []):
        return True
    if paragraph.find('a') and 'href' in str(paragraph):
        return True
    return False

# Function to process HTML content and extract relevant full text
def process_html(content):
    soup = BeautifulSoup(content, 'html.parser')
    paragraphs = soup.find_all('p')
    
    # Filter out irrelevant paragraphs and concatenate
    relevant_paragraphs = [str(p) for p in paragraphs if not is_irrelevant_paragraph(p)]
    full_text = ''.join(relevant_paragraphs)
    
    return full_text

# Creating a new dataframe for cleaned data
cleaned_data = []

for index, row in news_articles.iterrows():
    full_text = process_html(row["content"])
    cleaned_data.append({
        "link": row["link"],
        "title": row["title"],
        "content": full_text
    })

cleaned_articles = pd.DataFrame(cleaned_data)

#remove all emojis and <p class=""> tags from the content

def remove_emojis(text):
    return text.encode('ascii', 'ignore').decode('ascii')

def remove_p_tags(text):
    return re.sub(r'<p class=".*?">', '', text)

cleaned_articles['content'] = cleaned_articles['content'].apply(remove_emojis)

# Output the cleaned dataframe
display(cleaned_articles.head(3))  # Prints first few rows of the dataframe
len(cleaned_articles)
# Out:
#                                                 link  \
# 0  https://www.today.com/news/onewheel-electric-s...
# 1  https://www.today.com/news/powerball-no-winner...
# 2  https://www.today.com/popculture/travis-kelce-...
#
#                                                title  \
# 0  Onewheel electric skateboards recalled after 4...
# 1  Powerball draw produces no winners, pushing ja...
# 2  Travis Kelce and Chiefs hilariously trade Swif...
#
#                                              content
# 0  <p class="">The self-balancing skateboards, ma...
# 1  <p class="">Saturday nights Powerball lottery ...
# 2  <p class="">Travis is so proud, one fan commen...
# 1190

# %%
# delete the rows with content with less than 500 characters

cleaned_articles = cleaned_articles[cleaned_articles['content'].str.len() > 500]
len(cleaned_articles)
# Out:
# 1161

# %%
''' load the same tokenizer as the one used to train the model'''

tokenizer_sentiment = AutoTokenizer.from_pretrained("lxyuan/distilbert-base-multilingual-cased-sentiments-student")

# %%
''' define a function that takes a text as input and returns the sentiment label and score
if the text is too long, it will be truncated to 500 tokens'''

def get_sentiment(text):
    encoded_input = tokenizer_sentiment(
        text, 
        truncation=True, 
        max_length=500, 
        return_tensors=None
    )
    truncated_text = tokenizer_sentiment.decode(encoded_input["input_ids"])
    sentiment_check = pipeline(
        model="lxyuan/distilbert-base-multilingual-cased-sentiments-student", 
        top_k=3
    )
    sentiment_result = sentiment_check(truncated_text)

    # Extract the first label and score from the first list
    sentiment_label = sentiment_result[0][0]['label']
    sentiment_score = sentiment_result[0][0]['score']
    return sentiment_label, sentiment_score

# %%
''' For testing purposes create a short dataframe. Otherwise news_short = news
Assign the sentiment and score to the news_short then filter only the positive news as a new DataFrame'''

# display progress bar
from tqdm import tqdm

# Create a short dataframe for testing purposes
articles_short = cleaned_articles.copy().head(20)

# Create a new column for sentiment and score and apply the get_sentiment function with tqdm
tqdm.pandas()
articles_short[['sentiment', 'score']] = articles_short['content'].progress_apply(lambda x: pd.Series(get_sentiment(x)))

# Filter only the positive news as a new DataFrame that have a score higher than 0.5
positive_news = articles_short[(articles_short['sentiment'] == 'positive') & (articles_short['score'] > 0.5)]
# Out:
# 100%|██████████| 20/20 [00:41<00:00,  2.08s/it]

# %%
positive_news.sort_values(by=['score'], ascending=False).head(3)
# Out:
#                                                  link  \
# 8   https://www.today.com/food/creative-coffee-dri...
# 5   https://www.today.com/health/diet-fitness/star...
# 14  https://www.today.com/parents/dads/maya-hawke-...
#
#                                                 title  \
# 8          Creative coffee drinks for any time of day
# 5   We want to share your Start TODAY walking phot...
# 14  Ethan Hawke and daughter Maya Hawke release so...
#
#                                               content sentiment     score
# 8   <p class=""><em>(Sponsored by Folgers.)</em></...  positive  0.921967
# 5   <p class="">Are you one of the 550,000 Start T...  positive  0.808883
# 14  <p class="">Maya Hawke's parents, Ethan Hawke ...  positive  0.732843

# %%
import pandas as pd
from bs4 import BeautifulSoup
from transformers import AutoTokenizer

# Initialize a tokenizer
tokenizer_summary = AutoTokenizer.from_pretrained("facebook/bart-large-cnn")

# Function to split content into paragraphs
def split_into_paragraphs(content):
    soup = BeautifulSoup(content, 'html.parser')
    return [p.get_text().strip() for p in soup.find_all('p') if p.get_text().strip()]

# Function to group paragraphs with a token limit
def group_paragraphs(paragraphs, token_limit=900):
    grouped_paragraphs = []
    current_group = []
    current_count = 0

    for para in paragraphs:
        para_tokens = tokenizer_summary.tokenize(para)
        para_token_count = len(para_tokens)

        if current_count + para_token_count > token_limit and current_group:
            grouped_paragraphs.append(" ".join(current_group))
            current_group = []
            current_count = 0

        current_group.append(para)
        current_count += para_token_count

    if current_group:
        grouped_paragraphs.append(" ".join(current_group))

    return grouped_paragraphs

# Splitting content based on token count
paragraphs_data = []

for index, row in positive_news.iterrows():
    paragraphs = split_into_paragraphs(row["content"])
    total_tokens = sum(len(tokenizer_summary.tokenize(p)) for p in paragraphs)

    if total_tokens > 900:
        grouped_paras = group_paragraphs(paragraphs)
        for i, grouped_para in enumerate(grouped_paras):
            paragraphs_data.append({
                "link": row["link"],
                "title": row["title"],
                "paragraph_number": i + 1,
                "content": grouped_para
            })
    else:
        paragraphs_data.append({
            "link": row["link"],
            "title": row["title"],
            "paragraph_number": 1,
            "content": row["content"]
        })

paragraphs_df = pd.DataFrame(paragraphs_data)

# %%
paragraphs_df
# Out:
#                                                 link  \
# 0  https://www.today.com/health/diet-fitness/star...
# 1  https://www.today.com/food/creative-coffee-dri...
# 2  https://www.today.com/shop/self-care-bath-prod...
# 3  https://www.today.com/shop/self-care-bath-prod...
# 4  https://www.today.com/popculture/tv/dancing-wi...
# 5  https://www.today.com/parents/dads/maya-hawke-...
# 6  https://www.today.com/parents/dads/maya-hawke-...
# 7  https://www.today.com/life/holidays/celebrity-...
# 8  https://www.today.com/parents/celebrity/neil-p...
# 9  https://www.today.com/popculture/kardashian-je...
#
#                                                title  paragraph_number  \
# 0  We want to share your Start TODAY walking phot...                 1
# 1         Creative coffee drinks for any time of day                 1
# 2  Calm the chaos with these 22 spa-like products...                 1
# 3  Calm the chaos with these 22 spa-like products...                 2
# 4  Latin night says goodbye to one child star in ...                 1
# 5  Ethan Hawke and daughter Maya Hawke release so...                 1
# 6  Ethan Hawke and daughter Maya Hawke release so...                 2
# 7            The stars go all out for Halloween 2023                 1
# 8  Neil Patrick Harris and his family do the best...                 1
# 9  See the Kardashian-Jenner family’s sweet and s...                 1
#
#                                              content
# 0  <p class="">Are you one of the 550,000 Start T...
# 1  <p class=""><em>(Sponsored by Folgers.)</em></...
# 2  While it's nice to dream about regular facials...
# 3  Sometimes relaxing means sitting in the tub wi...
# 4  <p class="">Another celebrity's journey on "Da...
# 5  Maya Hawke's parents, Ethan Hawke and Uma Thur...
# 6  Thurman also opened up about what made it poss...
# 7  <p class="">This year, the spooky Oct. 31 holi...
# 8  <p class="">Step aside, pumpkins. Hold on to y...
# 9  <p class="">"So good!! ," one person said.</p>...

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# %%
from tqdm import tqdm
# Apply tqdm to show progress
tqdm.pandas()

def safe_summarize(text):
    try:
        summary = summarizer(text, max_length=300, min_length=50, do_sample=False, truncation=True)
        if summary:
            return summary[0]['summary_text']
        else:
            return "No summary available"
    except Exception as e:
        return f"Error in summarization: {str(e)}"

paragraphs_df['summary'] = paragraphs_df['content'].progress_apply(safe_summarize)

# Sort by 'link' and 'paragraph_number', then group by 'link' and join summaries
sorted_df = paragraphs_df.sort_values(by=['link', 'paragraph_number'])
final_df = sorted_df.groupby('link').agg({'title': 'first', 'summary': ' '.join}).reset_index()
# Out:
#  19%|█▉        | 8/42 [01:03<05:15,  9.29s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (1025 > 1024). Running this sequence through the model will result in indexing errors
#  90%|█████████ | 38/42 [06:28<00:38,  9.55s/it]Your max_length is set to 100, but your input_length is only 28. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=14)
# 100%|██████████| 42/42 [07:07<00:00, 10.40s/it]Your max_length is set to 100, but your input_length is only 88. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=44)
# 100%|██████████| 42/42 [07:12<00:00, 10.31s/it]
#                                                  link  \
# 0   https://www.today.com/food/creative-coffee-dri...
# 1   https://www.today.com/food/restaurants/taco-be...
# 2   https://www.today.com/health/diet-fitness/star...
# 3   https://www.today.com/health/mind-body/cat-pre...
# 4   https://www.today.com/health/pete-bridgette-wi...
# 5   https://www.today.com/life/holidays/blog/2023-...
# 6   https://www.today.com/life/holidays/celebrity-...
# 7   https://www.today.com/life/holidays/thanksgivi...
# 8   https://www.today.com/parents/celebrity/neil-p...
# 9   https://www.today.com/parents/dads/maya-hawke-...
# 10  https://www.today.com/popculture/heidi-klum-ha...
# 11  https://www.today.com/popculture/kardashian-je...
# 12  https://www.today.com/popculture/movies/witch-...
# 13  https://www.today.com/popculture/news/live-blo...
# 14  https://www.today.com/popculture/north-west-in...
# 15  https://www.today.com/popculture/today-show-ha...
# 16  https://www.today.com/popculture/tv/dancing-wi...
# 17  https://www.today.com/shop/11-best-gift-ideas-...
# 18  https://www.today.com/shop/amazon-holiday-beau...
# 19  https://www.today.com/shop/best-amazon-legging...
# 20  https://www.today.com/shop/best-gifts-21-year-...
# 21  https://www.today.com/shop/best-gifts-30-year-...
# 22  https://www.today.com/shop/best-slip-on-sneake...
# 23  https://www.today.com/shop/best-stocking-stuff...
# 24  https://www.today.com/shop/self-care-bath-prod...
# 25  https://www.today.com/shop/sephora-savings-eve...
#
#                                                 title  \
# 0          Creative coffee drinks for any time of day
# 1   Taco Bell is giving away its new breakfast tac...
# 2   We want to share your Start TODAY walking phot...
# 3   Woman went to her pulmonologist for COPD. Her ...
# 4   Pete Sampras reveals wife Bridgette has ovaria...
# 5   TODAY Halloween 2023 live updates: See all the...
# 6             The stars go all out for Halloween 2023
# 7   60 best Thanksgiving songs to play during dinn...
# 8   Neil Patrick Harris and his family do the best...
# 9   Ethan Hawke and daughter Maya Hawke release so...
# 10  Heidi Klum reveals her 'very, very big' 2023 H...
# 11  See the Kardashian-Jenner family’s sweet and s...
# 12              35 of the best witch movies ever made
# 13  Heidi Klum’s annual Halloween party underway i...
# 14  North West was asked who her style icon is. Yo...
# 15  How well do you know TODAY Halloween 2023? Tak...
# 16  Latin night says goodbye to one child star in ...
# 17  32 best gift ideas for seniors that they'll lo...
# 18  Amazon’s Holiday Beauty Haul has deals on Tatc...
# 19  Amazon reviewers can’t stop talking about thes...
# 20  Starting at $12, these gifts for 21-year-olds ...
# 21  45 gifts for 30-year-olds that will effortless...
# 22  Editors and experts swear by these slip-on sne...
# 23  The best surprises come in small packages, pro...
# 24  Calm the chaos with these 22 spa-like products...
# 25  Sephora is having an epic sitewide sale: Shop ...
#
#                                               summary
# 0   This drink is like the sophisticated, nuanced,...
# 1   Customers with a Taco Lovers Pass can choose f...
# 2    Send us a snap of your walk or run outdoors. ...
# 3   Dr. Earl King is a pulmonologist at Sentara RM...
# 4   Tennis legend Pete Sampras has revealed that h...
# 5   The whole gang is in on this years big Plaza r...
# 6   Error in summarization: index out of range in ...
# 7   Don Henley pays homage to baseball in his popu...
# 8   The family of four unveiled their Halloween 20...
# 9   Maya Hawke and her father, Ethan Hawke, record...
# 10  Error in summarization: index out of range in ...
# 11  Kourtney Kardashian Barker and Travis Barker d...
# 12  Every decade has its own brand of witch movies...
# 13  Heidi Klum's annual Halloween party kicked off...
# 14  The 10-year-old also talked about her love of ...
# 15  How well do you remember this years costumes? ...
# 16  Zoey 101 star Jamie Lynn Spears took a bow aft...
# 17  When it comes to gifts for seniors its all abo...
# 18  Error in summarization: index out of range in ...
# 19  Winter will be here before you know it, so fin...
# 20  The Chargetree Swing allows them to charge the...
# 21  The Legend of Zelda is a classic video game th...
# 22  Slip-on sneakers are easier to take on and off...
# 23  Crayola Color Wonder sets are mess-free marker...
# 24  Beauty writer Candice Kumai shares some easy-g...
# 25  Sephora's semi-annual site-wide sale has offic...

# %%
final_df
# Out:
#                                                  link  \
# 0   https://www.today.com/food/creative-coffee-dri...
# 1   https://www.today.com/food/restaurants/taco-be...
# 2   https://www.today.com/health/diet-fitness/star...
# 3   https://www.today.com/health/mind-body/cat-pre...
# 4   https://www.today.com/health/pete-bridgette-wi...
# 5   https://www.today.com/life/holidays/blog/2023-...
# 6   https://www.today.com/life/holidays/celebrity-...
# 7   https://www.today.com/life/holidays/thanksgivi...
# 8   https://www.today.com/parents/celebrity/neil-p...
# 9   https://www.today.com/parents/dads/maya-hawke-...
# 10  https://www.today.com/popculture/heidi-klum-ha...
# 11  https://www.today.com/popculture/kardashian-je...
# 12  https://www.today.com/popculture/movies/witch-...
# 13  https://www.today.com/popculture/news/live-blo...
# 14  https://www.today.com/popculture/north-west-in...
# 15  https://www.today.com/popculture/today-show-ha...
# 16  https://www.today.com/popculture/tv/dancing-wi...
# 17  https://www.today.com/shop/11-best-gift-ideas-...
# 18  https://www.today.com/shop/amazon-holiday-beau...
# 19  https://www.today.com/shop/best-amazon-legging...
# 20  https://www.today.com/shop/best-gifts-21-year-...
# 21  https://www.today.com/shop/best-gifts-30-year-...
# 22  https://www.today.com/shop/best-slip-on-sneake...
# 23  https://www.today.com/shop/best-stocking-stuff...
# 24  https://www.today.com/shop/self-care-bath-prod...
# 25  https://www.today.com/shop/sephora-savings-eve...
#
#                                                 title  \
# 0          Creative coffee drinks for any time of day
# 1   Taco Bell is giving away its new breakfast tac...
# 2   We want to share your Start TODAY walking phot...
# 3   Woman went to her pulmonologist for COPD. Her ...
# 4   Pete Sampras reveals wife Bridgette has ovaria...
# 5   TODAY Halloween 2023 live updates: See all the...
# 6             The stars go all out for Halloween 2023
# 7   60 best Thanksgiving songs to play during dinn...
# 8   Neil Patrick Harris and his family do the best...
# 9   Ethan Hawke and daughter Maya Hawke release so...
# 10  Heidi Klum reveals her 'very, very big' 2023 H...
# 11  See the Kardashian-Jenner family’s sweet and s...
# 12              35 of the best witch movies ever made
# 13  Heidi Klum’s annual Halloween party underway i...
# 14  North West was asked who her style icon is. Yo...
# 15  How well do you know TODAY Halloween 2023? Tak...
# 16  Latin night says goodbye to one child star in ...
# 17  32 best gift ideas for seniors that they'll lo...
# 18  Amazon’s Holiday Beauty Haul has deals on Tatc...
# 19  Amazon reviewers can’t stop talking about thes...
# 20  Starting at $12, these gifts for 21-year-olds ...
# 21  45 gifts for 30-year-olds that will effortless...
# 22  Editors and experts swear by these slip-on sne...
# 23  The best surprises come in small packages, pro...
# 24  Calm the chaos with these 22 spa-like products...
# 25  Sephora is having an epic sitewide sale: Shop ...
#
#                                               summary
# 0   This drink is like the sophisticated, nuanced,...
# 1   Customers with a Taco Lovers Pass can choose f...
# 2    Send us a snap of your walk or run outdoors. ...
# 3   Dr. Earl King is a pulmonologist at Sentara RM...
# 4   Tennis legend Pete Sampras has revealed that h...
# 5   The whole gang is in on this years big Plaza r...
# 6   Error in summarization: index out of range in ...
# 7   Don Henley pays homage to baseball in his popu...
# 8   The family of four unveiled their Halloween 20...
# 9   Maya Hawke and her father, Ethan Hawke, record...
# 10  Error in summarization: index out of range in ...
# 11  Kourtney Kardashian Barker and Travis Barker d...
# 12  Every decade has its own brand of witch movies...
# 13  Heidi Klum's annual Halloween party kicked off...
# 14  The 10-year-old also talked about her love of ...
# 15  How well do you remember this years costumes? ...
# 16  Zoey 101 star Jamie Lynn Spears took a bow aft...
# 17  When it comes to gifts for seniors its all abo...
# 18  Error in summarization: index out of range in ...
# 19  Winter will be here before you know it, so fin...
# 20  The Chargetree Swing allows them to charge the...
# 21  The Legend of Zelda is a classic video game th...
# 22  Slip-on sneakers are easier to take on and off...
# 23  Crayola Color Wonder sets are mess-free marker...
# 24  Beauty writer Candice Kumai shares some easy-g...
# 25  Sephora's semi-annual site-wide sale has offic...

# %%
prod_df = final_df.copy()

# %%
tqdm.pandas()
prod_df[['sentiment', 'score']] = prod_df['summary'].progress_apply(lambda x: pd.Series(get_sentiment(x)))

# Filter only the positive news as a new DataFrame that have a score higher than 0.5
prod_positive = prod_df[(prod_df['sentiment'] == 'positive') & (prod_df['score'] > 0.7)]
# Out:
# 100%|██████████| 26/26 [01:01<00:00,  2.36s/it]

# %%
prod_positive
# Out:
#                                                  link  \
# 0   https://www.today.com/food/creative-coffee-dri...
# 7   https://www.today.com/life/holidays/thanksgivi...
# 8   https://www.today.com/parents/celebrity/neil-p...
# 9   https://www.today.com/parents/dads/maya-hawke-...
# 14  https://www.today.com/popculture/north-west-in...
# 16  https://www.today.com/popculture/tv/dancing-wi...
# 17  https://www.today.com/shop/11-best-gift-ideas-...
# 20  https://www.today.com/shop/best-gifts-21-year-...
# 21  https://www.today.com/shop/best-gifts-30-year-...
# 22  https://www.today.com/shop/best-slip-on-sneake...
# 23  https://www.today.com/shop/best-stocking-stuff...
# 24  https://www.today.com/shop/self-care-bath-prod...
#
#                                                 title  \
# 0          Creative coffee drinks for any time of day
# 7   60 best Thanksgiving songs to play during dinn...
# 8   Neil Patrick Harris and his family do the best...
# 9   Ethan Hawke and daughter Maya Hawke release so...
# 14  North West was asked who her style icon is. Yo...
# 16  Latin night says goodbye to one child star in ...
# 17  32 best gift ideas for seniors that they'll lo...
# 20  Starting at $12, these gifts for 21-year-olds ...
# 21  45 gifts for 30-year-olds that will effortless...
# 22  Editors and experts swear by these slip-on sne...
# 23  The best surprises come in small packages, pro...
# 24  Calm the chaos with these 22 spa-like products...
#
#                                               summary sentiment     score
# 0   This drink is like the sophisticated, nuanced,...  positive  0.795621
# 7   Don Henley pays homage to baseball in his popu...  positive  0.836100
# 8   The family of four unveiled their Halloween 20...  positive  0.753958
# 9   Maya Hawke and her father, Ethan Hawke, record...  positive  0.878997
# 14  The 10-year-old also talked about her love of ...  positive  0.822209
# 16  Zoey 101 star Jamie Lynn Spears took a bow aft...  positive  0.705338
# 17  When it comes to gifts for seniors its all abo...  positive  0.779000
# 20  The Chargetree Swing allows them to charge the...  positive  0.866854
# 21  The Legend of Zelda is a classic video game th...  positive  0.824267
# 22  Slip-on sneakers are easier to take on and off...  positive  0.775693
# 23  Crayola Color Wonder sets are mess-free marker...  positive  0.889010
# 24  Beauty writer Candice Kumai shares some easy-g...  positive  0.872218

# %%
summary_df = prod_positive[['summary']]

# Exporting to CSV
summary_df.to_csv('summaries.csv', index=False)
